# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# fatal: destination path 'Mecab-ko-for-Google-Colab' already exists and is not an empty directory.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Requirement already satisfied: konlpy in /usr/local/lib/python3.11/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (1.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (5.4.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.11/dist-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from JPype1>=0.7.0->konlpy) (25.0)
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2025-07-20 19:35:45--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.143.21, 104.192.143.22, 104.192.143.23, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.143.21|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BND2R2UOBN&Signature=akw%2B%2BbjFx4YLtBtTH6fAqTQoU5k%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKz%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIGF8mnkWc6TEqbK%2BDDnFYHTNAj4oK3euucph5EuKvX%2FmAiEAss2oGuUCq0u2j9ePkNPuBtie9x9BEUpiGotE7VvSEMEqsAIIxP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw5ODQ1MjUxMDExNDYiDO8OasLOp4VrEFRpeyqEAmoZGBP6Ho9QrbFT6DzjhOmVLtx4ochMfx3dAGUjVdRKdxqeBp4J2WSZWttxqsNLzAZqzAESVWl%2FQ%2BnhM23HmPJsBbsyUI9Olp0fpO66P11Qpq7wEfhsytNRXYe3dkpUqnfV9i8PFmrps6Dcc9rvc%2F9YGzq4zh2zkyvo%2BSUvobbAdwYNIa0Df4akOBl2kj9O%2Buv5WfBG1CGjug6x3hhYps3wpAlPAvT%2BCauoK50qpOYPdyxqgr63yEQtRIXzlrIsnrWit0Sazd5JjTK70CiCpQUlC7ZneMAZH1HyRxjIk7HiwPOG4mIG0RBy3EmFkufjDD%2BtR1b%2B63U0ML889SPz35MQgj7YMMiD9cMGOp0B7NkgYyK%2Bz6doAO4fU0wy2aduIEQ4grkrsYJKBXezs5FFW2X4FpDdq5V2sKFAwCJqMVUwuxpChkv4ndUcPyT%2FNtMlTNiDSIeQWPuaRcLpqIoH70emd65mzFsL%2Fyg0YVu1O02ddIjym7GpAlyYH6DFc9mqsr0GV9Hjz93PTi1E5%2BPbPVxDXNb5t0JrgmEbSmr7wmWYrTuw4fE8Sng9CQ%3D%3D&Expires=1753041104 [following]
# --2025-07-20 19:35:46--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BND2R2UOBN&Signature=akw%2B%2BbjFx4YLtBtTH6fAqTQoU5k%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKz%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCIGF8mnkWc6TEqbK%2BDDnFYHTNAj4oK3euucph5EuKvX%2FmAiEAss2oGuUCq0u2j9ePkNPuBtie9x9BEUpiGotE7VvSEMEqsAIIxP%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw5ODQ1MjUxMDExNDYiDO8OasLOp4VrEFRpeyqEAmoZGBP6Ho9QrbFT6DzjhOmVLtx4ochMfx3dAGUjVdRKdxqeBp4J2WSZWttxqsNLzAZqzAESVWl%2FQ%2BnhM23HmPJsBbsyUI9Olp0fpO66P11Qpq7wEfhsytNRXYe3dkpUqnfV9i8PFmrps6Dcc9rvc%2F9YGzq4zh2zkyvo%2BSUvobbAdwYNIa0Df4akOBl2kj9O%2Buv5WfBG1CGjug6x3hhYps3wpAlPAvT%2BCauoK50qpOYPdyxqgr63yEQtRIXzlrIsnrWit0Sazd5JjTK70CiCpQUlC7ZneMAZH1HyRxjIk7HiwPOG4mIG0RBy3EmFkufjDD%2BtR1b%2B63U0ML889SPz35MQgj7YMMiD9cMGOp0B7NkgYyK%2Bz6doAO4fU0wy2aduIEQ4grkrsYJKBXezs5FFW2X4FpDdq5V2sKFAwCJqMVUwuxpChkv4ndUcPyT%2FNtMlTNiDSIeQWPuaRcLpqIoH70emd65mzFsL%2Fyg0YVu1O02ddIjym7GpAlyYH6DFc9mqsr0GV9Hjz93PTi1E5%2BPbPVxDXNb5t0JrgmEbSmr7wmWYrTuw4fE8Sng9CQ%3D%3D&Expires=1753041104
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 54.231.137.81, 3.5.12.159, 54.231.200.33, ...
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|54.231.137.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz.1’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  1.25MB/s    in 1.1s
#
# 2025-07-20 19:35:48 (1.25 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz.1’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2025-07-20 19:36:05--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.143.21, 104.192.143.22, 104.192.143.23, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.143.21|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNE65DMIS6&Signature=AecsrOQBWH4emcGnOe%2B6GylbUZ4%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKz%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCICAPwwQl6egaTQhGJQZ6gMOe6s1kMZVBRFQjvtZ3%2BFGAAiEAxaiYpVc81DE%2FjGMnVFWA0snEqImePfuY52QAtTMh7iMqsAIIxf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw5ODQ1MjUxMDExNDYiDIAruu4QhmxWeigMzSqEAqQllb%2BAmIVwEoLsLOJHD4EZxkv1l4PjG0hLnNFCTrjzCkKdfSnFVDIuJpmPiL1kmRXLMsIkUybfa5UNXh5FCMSD7nbazsdL%2Fyx0wjFpnkfMWXXMDb0agxiMjndU1YUhi0h38KuLZvDkZsrGH4nM3Sqy%2F7cOAi9nRPc9IEp%2FiC01BFS9tpza1xsEjqzYfcf7Ol0tL04stbLewmAosqOAJAmfnaq37qc%2Fq1br6hbgwwQuq8orQsVF8zXp8coGOpasvqRS0IdYfV8a3jie5XkQ7nVfET0hv7cAoS3Di2aKjMY4vzN51u3NdxVMpylPlJ5nVQxESPvRzmKwcv50t%2BFlNLHlqDknMMKE9cMGOp0BZRQMBEPrzgK99oyqpKjgTmRSRPAwNCZ%2B1uZhKmF1pxx9%2BnYr6zZl4nSoMlgbFjPXzpzLtz3XuQsmKDZnaP6lZXljPsUYtEsj1LMjFfR4Z8U1CjA181Zu6JIZhhae5EXhMAGKVxvihKbxe1hfHcqOjTAcg0esSQB%2FF%2Fzu3GLeSs3Q%2BkVJ1HFNq5GY4Dq2VDLRXIH22M1AyA2g6CrTgA%3D%3D&Expires=1753041226 [following]
# --2025-07-20 19:36:06--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNE65DMIS6&Signature=AecsrOQBWH4emcGnOe%2B6GylbUZ4%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEKz%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJHMEUCICAPwwQl6egaTQhGJQZ6gMOe6s1kMZVBRFQjvtZ3%2BFGAAiEAxaiYpVc81DE%2FjGMnVFWA0snEqImePfuY52QAtTMh7iMqsAIIxf%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARAAGgw5ODQ1MjUxMDExNDYiDIAruu4QhmxWeigMzSqEAqQllb%2BAmIVwEoLsLOJHD4EZxkv1l4PjG0hLnNFCTrjzCkKdfSnFVDIuJpmPiL1kmRXLMsIkUybfa5UNXh5FCMSD7nbazsdL%2Fyx0wjFpnkfMWXXMDb0agxiMjndU1YUhi0h38KuLZvDkZsrGH4nM3Sqy%2F7cOAi9nRPc9IEp%2FiC01BFS9tpza1xsEjqzYfcf7Ol0tL04stbLewmAosqOAJAmfnaq37qc%2Fq1br6hbgwwQuq8orQsVF8zXp8coGOpasvqRS0IdYfV8a3jie5XkQ7nVfET0hv7cAoS3Di2aKjMY4vzN51u3NdxVMpylPlJ5nVQxESPvRzmKwcv50t%2BFlNLHlqDknMMKE9cMGOp0BZRQMBEPrzgK99oyqpKjgTmRSRPAwNCZ%2B1uZhKmF1pxx9%2BnYr6zZl4nSoMlgbFjPXzpzLtz3XuQsmKDZnaP6lZXljPsUYtEsj1LMjFfR4Z8U1CjA181Zu6JIZhhae5EXhMAGKVxvihKbxe1hfHcqOjTAcg0esSQB%2FF%2Fzu3GLeSs3Q%2BkVJ1HFNq5GY4Dq2VDLRXIH22M1AyA2g6CrTgA%3D%3D&Expires=1753041226
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.217.70.124, 16.182.43.1, 52.217.102.252, ...
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.217.70.124|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz.1’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  13.1MB/s    in 4.2s
#
# 2025-07-20 19:36:11 (11.4 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz.1’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# apt-get update
# apt-get upgrade
# apt install curl
# apt install git
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Done
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.

# %%
# 위의 코드가 작동하지 않을 때 대안 코드 1 실행
# !pip install konlpy
# !pip install mecab-python
# !bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.11/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (1.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.11/dist-packages (from konlpy) (5.4.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.11/dist-packages (from konlpy) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from JPype1>=0.7.0->konlpy) (25.0)
# Collecting mecab-python
#   Downloading mecab-python-1.0.0.tar.gz (1.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mecab-python3 (from mecab-python)
#   Downloading mecab_python3-1.0.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Downloading mecab_python3-1.0.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.8/588.8 kB 3.9 MB/s eta 0:00:00
# Building wheels for collected packages: mecab-python
#   Building wheel for mecab-python (setup.py) ... done
#   Created wheel for mecab-python: filename=mecab_python-1.0.0-py3-none-any.whl size=1232 sha256=ffc40c097565871df2320fee14aa8eb8ff0eceacbf63937f4aa55ad6b424dba9
#   Stored in directory: /root/.cache/pip/wheels/a0/56/2c/eac72592ca2e80bdc46ff47d1fb327629e2a24e8cdc5aaf95f
# Successfully built mecab-python
# Installing collected packages: mecab-python3, mecab-python
# Successfully installed mecab-python-1.0.0 mecab-python3-1.0.10
# mecab-ko is already installed
# mecab-ko-dic is already installed
# mecab-python is already installed
# Done.

# %%
from konlpy.tag import Mecab
mecab = Mecab()
#NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요.

# %%
# 한글 자모 단위 처리 패키지 설치
# !pip install hgtk
# Out:
# Collecting hgtk
#   Downloading hgtk-0.2.1-py2.py3-none-any.whl.metadata (5.4 kB)
# Downloading hgtk-0.2.1-py2.py3-none-any.whl (12 kB)
# Installing collected packages: hgtk
# Successfully installed hgtk-0.2.1

# %%
# fasttext 설치
# !git clone https://github.com/facebookresearch/fastText.git
# %cd fastText
# !make
# !pip install .
# Out:
# Cloning into 'fastText'...
# remote: Enumerating objects: 3998, done.
# remote: Counting objects: 100% (995/995), done.
# remote: Compressing objects: 100% (171/171), done.
# remote: Total 3998 (delta 886), reused 824 (delta 824), pack-reused 3003 (from 2)
# Receiving objects: 100% (3998/3998), 8.30 MiB | 13.47 MiB/s, done.
# Resolving deltas: 100% (2527/2527), done.
# /content/Mecab-ko-for-Google-Colab/fastText
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/args.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/autotune.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/matrix.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/dictionary.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/loss.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/productquantizer.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/densematrix.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/quantmatrix.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/vector.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/model.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/utils.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/meter.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG -c src/fasttext.cc
# c++ -pthread -std=c++17 -march=native -O3 -funroll-loops -DNDEBUG args.o autotune.o matrix.o dictionary.o loss.o productquantizer.o densematrix.o quantmatrix.o vector.o model.o utils.o meter.o fasttext.o src/main.cc -o fasttext
# Processing /content/Mecab-ko-for-Google-Colab/fastText
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11>=2.2 (from fasttext==0.9.2)
#   Using cached pybind11-3.0.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from fasttext==0.9.2) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fasttext==0.9.2) (2.0.2)
# Using cached pybind11-3.0.0-py3-none-any.whl (292 kB)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (pyproject.toml) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp311-cp311-linux_x86_64.whl size=4508413 sha256=b4c6df521609a04a6cee144a0d600aedc944a3212c655a729e96b9ed09f9eb22
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2hrllsaz/wheels/22/83/a5/1506e7b3fd51df5006c412e3611aacc23b58d042b03c2f52b4
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-3.0.0

# %%
#hgtk 설치
# !pip install hgtk
# Out:
# Requirement already satisfied: hgtk in /usr/local/lib/python3.11/dist-packages (0.2.1)

# %% [markdown]
# ## 1. 데이터 로드

# %%
import re
import pandas as pd
import urllib.request
from tqdm import tqdm
import hgtk

# %%
# 네이버 쇼핑 리뷰
urllib.request.urlretrieve("https://raw.githubusercontent.com/bab2min/corpus/master/sentiment/naver_shopping.txt", filename="ratings_total.txt")
# Out:
# ('ratings_total.txt', <http.client.HTTPMessage at 0x7f6bf2e35710>)

# %%
total_data = pd.read_table('ratings_total.txt', names=['ratings', 'reviews'])
print('전체 리뷰 개수 :',len(total_data)) # 전체 리뷰 개수 출력
# Out:
# 전체 리뷰 개수 : 200000

# %%
total_data.head()
# Out:
#    ratings                                            reviews
# 0        5                                            배공빠르고 굿
# 1        2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 2        5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 3        2  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 4        5                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ

# %% [markdown]
# ## 2. hgtk 튜토리얼
#
#
#
# word embedding이 단어 단위의 임베딩이었다면, character embedding은 문자 단위의 임베딩입니다. 한국어를 character embedding할 수 있는 것이 바로 자음 모음 분리기 hgtk입니다.
#
#  영어는 하나의 알파벳(52자)를 기준으로 character embedding을 하지만, 한국어에서 하나의 음절별로 character embedding을 하면 11172개의 음절이 있기 때문에 계산량이 너무 많습니다. 따라서 그보다 작은 단위인 자음,모음으로 분리하는 것입니다.
#
#  >참고 repo: https://github.com/bluedisk/hangul-toolkit

# %%
# 한글인지 체크
print(hgtk.checker.is_hangul('ㄱ'))
print(hgtk.checker.is_hangul('12'))
print(hgtk.checker.is_hangul('a'))
# Out:
# True
# False
# False

# %%
# 음절을 초성, 중성, 종성으로 분해
print(hgtk.letter.decompose('남'))
# 초성, 중성, 종성을 하나의 음절로 결합
print(hgtk.letter.compose('ㄴ', 'ㅏ', 'ㅁ'))
# Out:
# ('ㄴ', 'ㅏ', 'ㅁ')
# 남

# %%
# 결합할 수 없는 상황에서는 에러 발생
try:
  hgtk.letter.compose('ㄴ', 'ㅁ', 'ㅁ') # 중성이 없는 경우
except:
  print('에러 발생')
# Out:
# 에러 발생

# %% [markdown]
# ## 3. 데이터 전처리

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def word_to_jamo(token):
  def to_special_token(jamo): # 경우에 따라 초, 중, 종성이 다 있는 게 아닌 경우도 있다. 이 경우 -를 반환해주는 함수
    if not jamo:
      return '-'
    else:
      return jamo

  decomposed_token = ''
  for char in token:
    try:
      # char(음절)을 초성, 중성, 종성으로 분리
      cho, jung, jong = hgtk.letter.decompose(char)

      # 자모가 빈 문자일 경우 특수문자 -로 대체
      cho = to_special_token(cho)
      jung = to_special_token(jung)
      jong = to_special_token(jong)
      decomposed_token = decomposed_token + cho + jung + jong

    # 만약 char(음절)이 한글이 아닐 경우 자모를 나누지 않고 추가
    except Exception as exception:
      if type(exception).__name__ == 'NotHangulException':
        decomposed_token += char

  # 단어 토큰의 자모 단위 분리 결과를 추가
  return decomposed_token

# %%
print(word_to_jamo('남동생'))
print(word_to_jamo('야구')) # 야구의 경우 종성이 없으므로 종성 부분을 -로 반환
# Out:
# ㄴㅏㅁㄷㅗㅇㅅㅐㅇ
# ㅇㅑ-ㄱㅜ-

# %%
print(mecab.morphs('선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다.'))
# Out:
# ['선물', '용', '으로', '빨리', '받', '아서', '전달', '했어야', '하', '는', '상품', '이', '었', '는데', '머그', '컵', '만', '와서', '당황', '했', '습니다', '.']

# %%
# mecab으로 형태소를 분리해주고 그 형태소마다 각각 자음모음을 분리해주는 함수
def tokenize_by_jamo(s):
    return [word_to_jamo(token) for token in mecab.morphs(s)]

# %%
print(tokenize_by_jamo('선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다.'))
# Out:
# ['ㅅㅓㄴㅁㅜㄹ', 'ㅇㅛㅇ', 'ㅇㅡ-ㄹㅗ-', 'ㅃㅏㄹㄹㅣ-', 'ㅂㅏㄷ', 'ㅇㅏ-ㅅㅓ-', 'ㅈㅓㄴㄷㅏㄹ', 'ㅎㅐㅆㅇㅓ-ㅇㅑ-', 'ㅎㅏ-', 'ㄴㅡㄴ', 'ㅅㅏㅇㅍㅜㅁ', 'ㅇㅣ-', 'ㅇㅓㅆ', 'ㄴㅡㄴㄷㅔ-', 'ㅁㅓ-ㄱㅡ-', 'ㅋㅓㅂ', 'ㅁㅏㄴ', 'ㅇㅘ-ㅅㅓ-', 'ㄷㅏㅇㅎㅘㅇ', 'ㅎㅐㅆ', 'ㅅㅡㅂㄴㅣ-ㄷㅏ-', '.']

# %%
# 리뷰 데이터의 reviews 컬럼만을 가져와서 자모 분리
tokenized_data = []

for sample in tqdm(total_data['reviews'].to_numpy()):
    tokenzied_sample = tokenize_by_jamo(sample) # 자소 단위 토큰화
    tokenized_data.append(tokenzied_sample)
# Out:
# 100%|██████████| 200000/200000 [00:59<00:00, 3374.02it/s]

# %%
print(len(tokenized_data))
print("전처리 전:", total_data['reviews'][1])
print("전처리 후:", tokenized_data[1])
# Out:
# 200000
# 전처리 전: 택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 전처리 후: ['ㅌㅐㄱㅂㅐ-', 'ㄱㅏ-', 'ㅇㅓㅇㅁㅏㅇ', 'ㅇㅣ-', 'ㄴㅔ-', 'ㅇㅛㅇ', 'ㅈㅓ-ㅎㅢ-', 'ㅈㅣㅂ', 'ㅁㅣㅌ', 'ㅇㅔ-', 'ㅊㅡㅇ', 'ㅇㅔ-', 'ㅁㅏㄹ', 'ㄷㅗ-', 'ㅇㅓㅄㅇㅣ-', 'ㄴㅘ-ㄷㅜ-', 'ㄱㅗ-', 'ㄱㅏ-', 'ㄱㅗ-']

# %% [markdown]
# 단어를 자모 분리한 것을 역으로 하여 자모 상태를 단어로 다시 결합시키는 함수도 정의해봅시다. 이는 단어의 코사인 유사도를 평가할 때 자모 분리가 된 상태가 아니라 단어 상태로 편리하게 보기 위함입니다.

# %%
def jamo_to_word(jamo_sequence):
  tokenized_jamo = []
  index = 0

  # 1. 초기 입력
  # jamo_sequence = 'ㄴㅏㅁㄷㅗㅇㅅㅐㅇ'

  while index < len(jamo_sequence):
    # 문자가 한글(정상적인 자모)이 아닐 경우
    if not hgtk.checker.is_hangul(jamo_sequence[index]):
      tokenized_jamo.append(jamo_sequence[index])
      index = index + 1

    # 문자가 정상적인 자모라면 초성, 중성, 종성을 하나의 토큰으로 간주.
    else:
      tokenized_jamo.append(jamo_sequence[index:index + 3])
      index = index + 3

  # 2. 자모 단위 토큰화 완료
  # tokenized_jamo : ['ㄴㅏㅁ', 'ㄷㅗㅇ', 'ㅅㅐㅇ']

  word = ''
  try:
    for jamo in tokenized_jamo:

      # 초성, 중성, 종성의 묶음으로 추정되는 경우
      if len(jamo) == 3:
        if jamo[2] == "-":
          # 종성이 존재하지 않는 경우
          word = word + hgtk.letter.compose(jamo[0], jamo[1])
        else:
          # 종성이 존재하는 경우
          word = word + hgtk.letter.compose(jamo[0], jamo[1], jamo[2])
      # 한글이 아닌 경우
      else:
        word = word + jamo

  # 복원 중(hgtk.letter.compose) 에러 발생 시 초기 입력 리턴.
  # 복원이 불가능한 경우 예시) 'ㄴ!ㅁㄷㅗㅇㅅㅐㅇ'
  except Exception as exception:
    if type(exception).__name__ == 'NotHangulException':
      return jamo_sequence

  # 3. 단어로 복원 완료
  # word : '남동생'

  return word

# %% [markdown]
# ## 4. FastText

# %%
import fasttext

# %% [markdown]
# fasttext를 실행하기에 앞서 훈련 대상인 단어들을 txt 파일로 준비해둬야 합니다. 따라서 `tokenized_data.txt`라는 파일을 쓰기 모드(w)로 생성해주고 앞서 전처리한 `tokenized_data`를 입력해줍니다.

# %%
with open('tokenized_data.txt', 'w') as out:
  for line in tqdm(tokenized_data, unit=' line'):
    out.write(' '.join(line) + '\n')
# Out:
# 100%|██████████| 200000/200000 [00:00<00:00, 280109.99 line/s]

# %% [markdown]
# 아래처럼 `train_unsupeviesd` 함수는 훈련을 시켜주는 함수입니다. 인자로 훈련할 단어가 담긴 txt 파일을 지정하고 model을 `cbow`나 `skipgram` 중에 하나를 고르면 됩니다.

# %%
model = fasttext.train_unsupervised('tokenized_data.txt', model='cbow')

# %%
model.save_model("fasttext.bin")

# %%
model = fasttext.load_model("fasttext.bin")

# %%
model[word_to_jamo('남동생')] # 'ㄴㅏㅁㄷㅗㅇㅅㅐㅇ'
# Out:
# array([ 0.20013799,  0.88953376,  0.58970124, -0.5847397 , -0.9659391 ,
#        -0.7410927 , -0.17766874,  0.90158886, -0.34152293, -0.7123099 ,
#         0.6441236 ,  0.42982963, -0.40837348,  0.7511313 , -0.09309892,
#         0.7347375 ,  0.27207386,  0.3949261 ,  0.35518122,  0.36587685,
#         0.5071332 , -0.15160936,  0.47952434, -0.54048634, -0.10248369,
#        -0.35038233,  0.04594525,  1.1051015 ,  0.61694676, -0.717945  ,
#         0.30392155, -0.47688827,  0.39025903, -0.5179225 ,  1.4891224 ,
#         0.33211136,  0.26518908,  0.359716  , -0.05618792,  0.17526521,
#         0.77264774, -0.26265436,  0.097826  ,  0.02990593,  0.06724232,
#        -0.8136393 ,  0.10142293,  0.5821607 ,  0.17145617, -0.38708758,
#        -0.19268256, -0.27410623,  0.19634488, -0.13674155, -0.98964244,
#        -0.1965299 ,  0.36816007,  0.5520197 , -0.40526402,  0.36485967,
#         0.06126729, -0.72642136,  0.13195199,  0.8948129 , -0.28386012,
#         0.45280063,  0.00418409, -0.51872003, -0.25479087,  0.24888143,
#        -0.68064827, -0.35977957,  0.4763949 ,  0.09211579,  0.33814162,
#        -0.9967398 , -0.33495456, -0.29187903,  0.20709333,  0.06315663,
#         1.1449215 ,  0.7202959 , -0.40129808,  0.8562797 ,  0.4888471 ,
#        -0.07463529, -0.60865116, -0.80039257,  0.69243777, -0.09130275,
#         0.10606896, -0.00943482, -0.5302925 , -0.8702011 , -1.1332687 ,
#         1.212212  ,  0.27479073,  0.4217211 , -0.4379071 ,  0.49377784],
#       dtype=float32)

# %% [markdown]
# `get_nearest_neighbors` 함수를 사용하여 '남동생'이라는 단어와 가장 유사도가 높은 단어들(자모 분리된 상태)을 k개만큼 출력해줍니다.

# %%
model.get_nearest_neighbors(word_to_jamo('남동생'), k=10)
# Out:
# [(0.8896068930625916, 'ㄷㅗㅇㅅㅐㅇ'),
#  (0.842293918132782, 'ㄴㅏㅁㅊㅣㄴ'),
#  (0.7658187747001648, 'ㅊㅣㄴㄱㅜ-'),
#  (0.7444283962249756, 'ㄴㅏㅁㅍㅕㄴ'),
#  (0.742219090461731, 'ㄴㅏㅁㅇㅏ-'),
#  (0.740485429763794, 'ㅈㅗ-ㅋㅏ-'),
#  (0.7209845781326294, 'ㅅㅐㅇㅇㅣㄹ'),
#  (0.7175430655479431, 'ㅈㅜㅇㅎㅏㄱㅅㅐㅇ'),
#  (0.7064188718795776, 'ㅎㅏㄱㅅㅐㅇ'),
#  (0.7031176686286926, 'ㄴㅏㄴㅅㅐㅇ')]

# %% [markdown]
# 앞서 만든 `jamo_to_word`로 가독성이 좋게 출력해봅시다.

# %%
def transform(word_sequence):
  return [(jamo_to_word(word), similarity) for (similarity, word) in word_sequence]

# %%
print(transform(model.get_nearest_neighbors(word_to_jamo('남동생'), k=10)))
print(transform(model.get_nearest_neighbors(word_to_jamo('구매'), k=10)))
print(transform(model.get_nearest_neighbors(word_to_jamo('배달'), k=10)))
# Out:
# [('동생', 0.8896068930625916), ('남친', 0.842293918132782), ('친구', 0.7658187747001648), ('남편', 0.7444283962249756), ('남아', 0.742219090461731), ('조카', 0.740485429763794), ('생일', 0.7209845781326294), ('중학생', 0.7175430655479431), ('학생', 0.7064188718795776), ('난생', 0.7031176686286926)]
# [('구매처', 0.8442402482032776), ('구입', 0.8113102316856384), ('주문', 0.7216742038726807), ('주문건', 0.6721146702766418), ('주문서', 0.6225589513778687), ('구메', 0.5995639562606812), ('헤매', 0.5936337113380432), ('구매자', 0.5771390795707703), ('삼다수', 0.56662517786026), ('시커매', 0.5638571381568909)]
# [('배송지', 0.7850454449653625), ('매달', 0.759340763092041), ('깨달', 0.7592893838882446), ('출고가', 0.7200115919113159), ('운송', 0.7193134427070618), ('운송장', 0.7191582322120667), ('발송', 0.7184928059577942), ('배소', 0.7184908986091614), ('직송', 0.7130810022354126), ('메달', 0.711025059223175)]

# %% [markdown]
# ## 5. Word2Vec
#
# ![image.png](attachment:image.png)
# 이제 word2vec를 사용하여 자모 단위로 분리하는 것이 아닌 단어 단위로 분리하여 임베딩 벡터를 생성해볼 것입니다.

# %%
# 간단하게 불용어 정의
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

tokenized_data2 = []
for sentence in tqdm(total_data['reviews'].to_list()):
    tokenized_sentence = mecab.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    tokenized_data2.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 200000/200000 [00:21<00:00, 9383.37it/s]

# %%
print("word2vec용 데이터:", tokenized_data2[0])
print("fasttext용 데이터:", tokenized_data[0])
# Out:
# word2vec용 데이터: ['배공', '빠르', '고', '굿']
# fasttext용 데이터: ['ㅂㅐ-ㄱㅗㅇ', 'ㅃㅏ-ㄹㅡ-', 'ㄱㅗ-', 'ㄱㅜㅅ']

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.2 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 42.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 59.8 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 12.7 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
from gensim.models import Word2Vec

model2 = Word2Vec(sentences = tokenized_data2, vector_size = 1000, window = 5, min_count = 5, workers = 4, sg = 0)

# %%
# 완성된 임베딩 매트릭스의 크기 확인
# 단어의 총 개수는 15005개이고 벡터 차원은 1000으로 축소되었다.
model2.wv.vectors.shape
# Out:
# (15005, 1000)

# %% [markdown]
# ## 6. FastText와 Word2Vec 결과 비교

# %% [markdown]
# ### **Q1) 남동생과 주문 두 단어를 input으로 넣고 결과를 비교한 뒤 해석해보세요**
#
# *(Hint: 유사도, 단어의 의미, 단어의 생김새 등을 고려해 볼 수 있습니다)*

# %%
print("FastText 유사도:", transform(model.get_nearest_neighbors(word_to_jamo('남동생'), k=10)))
print("Word2Vec 유사도:", model2.wv.most_similar("남동생"))
# Out:
# FastText 유사도: [('동생', 0.8896068930625916), ('남친', 0.842293918132782), ('친구', 0.7658187747001648), ('남편', 0.7444283962249756), ('남아', 0.742219090461731), ('조카', 0.740485429763794), ('생일', 0.7209845781326294), ('중학생', 0.7175430655479431), ('학생', 0.7064188718795776), ('난생', 0.7031176686286926)]
# Word2Vec 유사도: [('입학', 0.7047216892242432), ('결혼', 0.6992394328117371), ('어린이날', 0.6992236375808716), ('오빠', 0.6964209675788879), ('사촌', 0.6939277648925781), ('고등학교', 0.6848036050796509), ('개업', 0.6847288608551025), ('중학생', 0.6826469898223877), ('외할머니', 0.6807249784469604), ('앞둔', 0.6768578886985779)]

# %%
print("FastText 유사도:", transform(model.get_nearest_neighbors(word_to_jamo('주문'), k=10)))
print("Word2Vec 유사도:", model2.wv.most_similar("주문"))
# Out:
# FastText 유사도: [('주문건', 0.8997762203216553), ('주문서', 0.8490602970123291), ('구입', 0.7459090352058411), ('주문자', 0.7358319759368896), ('구매', 0.721674382686615), ('주무시', 0.7160824537277222), ('주무', 0.7118440270423889), ('시켰', 0.6956518888473511), ('시켰었', 0.6926632523536682), ('구매처', 0.6610974669456482)]
# Word2Vec 유사도: [('구매', 0.8277290463447571), ('구입', 0.8273687362670898), ('선택', 0.6199406981468201), ('시켰', 0.5642427802085876), ('결제', 0.5538167357444763), ('도전', 0.5289210677146912), ('신청', 0.5235692858695984), ('교체', 0.5189570188522339), ('시킨', 0.5097692012786865), ('준비', 0.5088452100753784)]

# %% [markdown]
# **Your Inference:**
#
# 남동생
# - FastText의 경우, '남친', '남편' 과 같이 '남'으로 시작하는 단어들과 '동생',''생일'과 같이 '생'이 들어가는 단어들이 나왔다
# - Word2Vec은 '어머님', '둥이'(귀염둥이 등에서의 접미사), '여친' 등 '남동생'과 문맥적으로 함께 자주 등장할 만한 단어들을 제시한다.
# - FastText는 **문자 단위 임베딩**을 사용하기 때문에 단어의 형태적 유사성을 고려하여 '남'이라는 어간이 포함된, 의미가 유사한 단어들을 잘 추출하며, 단어의 **형태적 유사성**을 잘 파악한다. 반면 Word2Vec이 단어 단위 임베딩을 사용하기에 단어의 **의미적 유사성 및 맥락상 함께 등장하는 단어들**을 파악하려고 하지만, 남동생의 경우 의미적 유사성을 가진 단어들을 잘 추출하지 못한 것으로 보인다. 이는 학습 코퍼스의 제한으로 인한 것일 수 있다. 특히 '남동생'의 경우, 단어에 포함된 '남'이라는 어간이 뜻을 나타내는 핵심이므로 문자의 형태적 유사성을 잘 포착하는 FastText의 결과가 더 좋은 것 같다.
#
# 주문
# - FastText의 경우 '주문'이라는 단어가 포함된 '주문건' 및 '주문서'와 '구입', '구매', '구매처'등 온라인 쇼핑과 관련된 단어들을 제시했다.
# - Word2Vec '구매','구입' 등 온라인 쇼핑 관련 단어를 동일하게 주는 반면,'결제', '준비', '도착' 등 '주문'과 의미적으로 관련된 다양한 단어들을 제시한다.
# - '주문'이라는 단어의 경우 온라인 쇼핑에서의 핵심 단어이기에 두 모델 모두 유사도가 높은, 관련성이 높은 단어들을 추출하는 경향이 있는 것 같다. 특히 FastText의 경우 역시 단어의 형태적 유사성을 고려하기에 '주문'이라는 단어 자체가 포함된 단어들도 잘 제시하지만, 여기다가 단어의 문맥 정보를 어느 정도 고려하여 형태적 유사성이 떨어지더라도 '주문'과 유사한 문맥에서 사용되거나 함께 자주 등장하는 '구입' '구매'와 같은 단어까지 추출해낸다는 점이 주목할 만하다.

# %% [markdown]
# ### **Q2) Fasttext가 Word2Vec보다 항상 성능이 나은지 다양한 input을 넣어서 시도해보세요**

# %%
print("FastText 유사도:", transform(model.get_nearest_neighbors(word_to_jamo('학생'), k=10)))
print("Word2Vec 유사도:", model2.wv.most_similar("학생"))
# Out:
# FastText 유사도: [('중학생', 0.8601469993591309), ('초등학생', 0.8563629984855652), ('고등학생', 0.8220496773719788), ('학교', 0.7959598898887634), ('동생', 0.7665697336196899), ('남동생', 0.7064188122749329), ('어린이집', 0.7033388614654541), ('학습', 0.6949698328971863), ('중학교', 0.6934248805046082), ('고등학교', 0.685539722442627)]
# Word2Vec 유사도: [('등산', 0.7620226144790649), ('사춘기', 0.7447257041931152), ('탁상', 0.7275216579437256), ('가림', 0.713569700717926), ('어린이', 0.7131509780883789), ('입문', 0.7123424410820007), ('트레이닝', 0.7109072208404541), ('저학년', 0.7099004983901978), ('유아', 0.7077659964561462), ('패션', 0.7021971344947815)]

# %%
print("FastText 유사도:", transform(model.get_nearest_neighbors(word_to_jamo('음식'), k=10)))
print("Word2Vec 유사도:", model2.wv.most_similar("음식"))
# Out:
# FastText 유사도: [('음식물', 0.8672635555267334), ('음식점', 0.8461788296699524), ('식물', 0.7625084519386292), ('식', 0.7276446223258972), ('양식', 0.7067604660987854), ('소식', 0.7008881568908691), ('첨가물', 0.6920824646949768), ('야식', 0.6889671087265015), ('도식', 0.6887546181678772), ('생식', 0.674808919429779)]
# Word2Vec 유사도: [('과일', 0.7647570371627808), ('밥', 0.7269456386566162), ('과자', 0.6858065724372864), ('우유', 0.68056321144104), ('김치', 0.6783908009529114), ('야채', 0.6689248085021973), ('양념', 0.6654505133628845), ('소금', 0.6602889895439148), ('꿀', 0.6574223637580872), ('국물', 0.6541586518287659)]

# %%
print("FastText 유사도:", transform(model.get_nearest_neighbors(word_to_jamo('야구'), k=10)))
print("Word2Vec 유사도:", model2.wv.most_similar("야구"))
# Out:
# FastText 유사도: [('도구', 0.7494287490844727), ('냐구', 0.7393714785575867), ('요구', 0.7230044007301331), ('수구', 0.6910877227783203), ('야겠다', 0.6882814764976501), ('야자수', 0.6862784028053284), ('야자', 0.6783844232559204), ('호구', 0.6705006957054138), ('복구', 0.664484977722168), ('야기', 0.6640432476997375)]
# Word2Vec 유사도: [('연습장', 0.8130539655685425), ('드로즈', 0.8055947422981262), ('유니', 0.7987679839134216), ('직사각', 0.7918812036514282), ('두리', 0.7908433675765991), ('혈', 0.7898309826850891), ('페트', 0.7869452238082886), ('PC', 0.7802115678787231), ('서버', 0.7796736359596252), ('니버', 0.7778416872024536)]

# %%
print("FastText 유사도:", transform(model.get_nearest_neighbors(word_to_jamo('엘지'), k=10)))
print("Word2Vec 유사도:", model2.wv.most_similar("엘지"))
# Out:
# FastText 유사도: [('찰지', 0.9199706315994263), ('골지', 0.9057568907737732), ('올지', 0.8935906291007996), ('말지', 0.8843898773193359), ('질지', 0.8712306022644043), ('일지', 0.8687199354171753), ('줄지', 0.8673567175865173), ('갈지', 0.8633836507797241), ('달지', 0.8620054125785828), ('을지', 0.8604585528373718)]
# Word2Vec 유사도: [('서버', 0.7786545157432556), ('농협', 0.7580521106719971), ('PC', 0.7566497921943665), ('자사', 0.7484757304191589), ('유니', 0.7405106425285339), ('수산', 0.7384577393531799), ('tv', 0.7378775477409363), ('시거', 0.7374441623687744), ('주차장', 0.7363836169242859), ('헤드셋', 0.736300528049469)]

# %% [markdown]
# **Your Inference:** 입력한 단어의 특징?에 따라 결과가 다르게 나타난다.
#
# FastText이 나은 경우
# - 단어 내에 단어의 의미를 유의미하게 나타내는 어간이 포함되거나, 다른 어간과 결합하여 많은 단어를 나타내는 어간일 경우 FastText의 성능이 좋다. 예를 들어 아까 제시된 '남동생'과 같이 단어 의미에서의 핵심인 어간(남)이 포함된 경우. '학생'과 같이 다른 어간들과 결합하여 생성된 '중학생', '초등학생' 등의 단어가 있는 경우 형태학적인 유사성이 큰 단어들이 의미적 유사성도 크기에 FastText가 형태적으로 유사한 단어들을 제시하는 게 결국 의미적 유사성으로 이어지는 경향이 있다.
#
# Word2Vec이 나은 경우
# - 의미를 나타내는 유의미한 어간이 없는 경우에 Word2Vec의 성능이 더 좋은 것 같다. '엘지...'의 경우에는 FastText는 의미적으로 연관이 없지만 '지'가 들어간, 형태적으로 유사한 단어들을 제시한다. 그러나 '지'가 가 의미에 있어서 유의미한 부분이 아니기에 이러한 FastText의 N-gram 기능이 발휘하지 못한다.
#
# 추가로
# - 음식은 '식'이라는 부분으로 FastText의 성능이 좋은 동시에 Word2vec에서도 의미적으로도 먹을 거리가 많이 출력되었다. 반면, 야구 같은 경우에는 입력 코퍼스의 한계 떄문인 것인지 두 모델 모두에 대해서 그렇게까지 유의한 단어가 나오지는 않았다.
#
# 종합적으로
# - 한글의 경우에는 어간의 역할이 큰 경우가 많기에, 이런 단어들에 대해서는 FastText의 성능이 좋으며,나아가 학습 데이터가 부족하거나 짧은 텍스트인 경우에도, 적은 데이터로도 단어 유사성 학습이 가능하고 단어의 등장 빈도가 그렇게 크게 영향을 미치지 않는 FastText의 성능이 더 좋을 것이다. 반면 단어가 딱히 형태소로 이루어져있지 않거나, 외래어인 경우, 또 단어의 의미가 문맥에 따라 크게 바뀌는 경우 (동음이의어) Word2Vec의 성능이 좋을 것이라고 유추할 수 있으며, 학습 데이터가 충분한 경우에도 Word2Vec이 FastText보다 정확한 단어 임베딩을 생성할 가능성이 있다.
